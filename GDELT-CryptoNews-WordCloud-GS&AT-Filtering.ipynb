# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("GDELT-CryptoNews-BQ-Results-and-Bitcoin-ClosingPrice-final_v3.xlsx")

# %%
df
# Out:
#                ID  Classification  \
# 0      1030957178         BITCOIN
# 1      1030993451         BITCOIN
# 2      1030834711         BITCOIN
# 3      1030951118         BITCOIN
# 4      1030838195         BITCOIN
# ...           ...             ...
# 27513   813535638         BITCOIN
# 27514   813515698  CRYPTOCURRENCY
# 27515   813501525  CRYPTOCURRENCY
# 27516   813517140  CRYPTOCURRENCY
# 27517   813467504  CRYPTOCURRENCY
#
#                                                     Link      Date Country  \
# 0      https://markets.businessinsider.com/news/curre...  20220228      US
# 1      https://www.wzzm13.com/article/news/crime/geek...  20220228      XX
# 2      https://foreignaffairs.co.nz/2022/02/28/mil-os...  20220228      JM
# 3      https://www.newsweek.com/ukraine-military-russ...  20220228      RS
# 4      https://economictimes.indiatimes.com/markets/c...  20220228      KS
# ...                                                  ...       ...     ...
# ...

# %%
GP_TP = df.loc[(df['GoldsteinScale'] > 0 ) & (df['AvgTone'] > 0)]

# %%
GP_TP
# Out:
#                ID Classification  \
# 2      1030834711        BITCOIN
# 6      1030961244        BITCOIN
# 7      1030968768        BITCOIN
# 8      1030883563        BITCOIN
# 18     1030818602        BITCOIN
# ...           ...            ...
# 27498   813640181        BITCOIN
# 27499   813609521        BITCOIN
# 27500   813699827        BITCOIN
# 27508   813500424        BITCOIN
# 27513   813535638        BITCOIN
#
#                                                     Link      Date Country  \
# 2      https://foreignaffairs.co.nz/2022/02/28/mil-os...  20220228      JM
# 6      https://marylandreporter.com/2022/02/28/bitcoi...  20220228      XX
# 7      https://bitcoinke.io/2022/02/we-will-introduce...  20220228      SF
# 8      http://www.itechpost.com/articles/109318/20220...  20220228      UP
# 18     https://www.asiaone.com/business/cs-global-par...  20220228      ES
# ...                                                  ...       ...     ...
# ...

# %%
GP_TP.to_excel("GDELT-CryptoNews-WordCloud-GoldsteinScaleP-AvgToneP.xlsx",index=False)

# %%
GP_TN = df.loc[(df['GoldsteinScale'] > 0 ) & (df['AvgTone'] < 0)]

# %%
GP_TN
# Out:
#                ID  Classification  \
# 3      1030951118         BITCOIN
# 11     1031010498         BITCOIN
# 12     1030948253         BITCOIN
# 15     1030823141         BITCOIN
# 16     1031007253         BITCOIN
# ...           ...             ...
# 27504   813644704  CRYPTOCURRENCY
# 27505   813675290  CRYPTOCURRENCY
# 27506   813604394  CRYPTOCURRENCY
# 27511   813485027         BITCOIN
# 27514   813515698  CRYPTOCURRENCY
#
#                                                     Link      Date Country  \
# 3      https://www.newsweek.com/ukraine-military-russ...  20220228      RS
# 11     https://www.msn.com/en-us/news/technology/bitc...  20220228      UK
# 12     https://www.datacenterdynamics.com/en/news/kaz...  20220228      CH
# 15     https://www.news.com.au/finance/markets/world-...  20220228      UP
# 16     https://www.theverge.com/2022/2/28/22954859/bi...  20220228      CH
# ...                                                  ...       ...     ...
# ...

# %%
GP_TN.to_excel("GDELT-CryptoNews-WordCloud-GoldsteinScaleP-AvgToneN.xlsx",index=False)

# %%
GN_TP = df.loc[(df['GoldsteinScale'] < 0 ) & (df['AvgTone'] > 0)]

# %%
GN_TP
# Out:
#                ID  Classification  \
# 39     1030784865         BITCOIN
# 83     1030592111  CRYPTOCURRENCY
# 86     1030646496  CRYPTOCURRENCY
# 141    1030000826         BITCOIN
# 143    1030085408         BITCOIN
# ...           ...             ...
# 27446   814116539         BITCOIN
# 27458   813814237         BITCOIN
# 27479   813745863  CRYPTOCURRENCY
# 27484   813847371  CRYPTOCURRENCY
# 27516   813517140  CRYPTOCURRENCY
#
#                                                     Link      Date Country  \
# 39     https://bitcoinmagazine.com/business/buying-an...  20220227      US
# 83     https://www.thestreet.com/investing/cryptocurr...  20220226      CH
# 86     https://edmontonjournal.com/news/local-news/gl...  20220226      CA
# 141    https://www.stripes.com/theaters/us/2022-02-23...  20220224      CH
# 143    https://kuow.org/stories/how-the-u-s-benefits-...  20220224      CH
# ...                                                  ...       ...     ...
# ...

# %%
GN_TP.to_excel("GDELT-CryptoNews-WordCloud-GoldsteinScaleN-AvgToneP.xlsx",index=False)

# %%
GN_TN = df.loc[(df['GoldsteinScale'] < 0 ) & (df['AvgTone'] < 0)]

# %%
GN_TN
# Out:
#                ID  Classification  \
# 0      1030957178         BITCOIN
# 4      1030838195         BITCOIN
# 5      1030829521         BITCOIN
# 9      1030873105         BITCOIN
# 10     1030814106         BITCOIN
# ...           ...             ...
# 27502   813553870  CRYPTOCURRENCY
# 27503   813681049  CRYPTOCURRENCY
# 27507   813540269         BITCOIN
# 27512   813466107         BITCOIN
# 27517   813467504  CRYPTOCURRENCY
#
#                                                     Link      Date Country  \
# 0      https://markets.businessinsider.com/news/curre...  20220228      US
# 4      https://economictimes.indiatimes.com/markets/c...  20220228      KS
# 5      https://forextv.com/bitcoin-news/investors-fle...  20220228      UP
# 9      https://menafn.com/1103773134/Bitcoin-Hackers-...  20220228      UK
# 10     https://www.investing.com/news/cryptocurrency-...  20220228      UP
# ...                                                  ...       ...     ...
# ...

# %%
GN_TN.to_excel("GDELT-CryptoNews-WordCloud-GoldsteinScaleN-AvgToneN.xlsx",index=False)
