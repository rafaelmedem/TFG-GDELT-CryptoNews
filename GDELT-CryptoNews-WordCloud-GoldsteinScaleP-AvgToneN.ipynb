# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("GDELT-CryptoNews-WordCloud-GoldsteinScaleP-AvgToneN.xlsx")

# %%
df
# Out:
#               ID  Classification  \
# 0     1030951118         BITCOIN
# 1     1031010498         BITCOIN
# 2     1030948253         BITCOIN
# 3     1030823141         BITCOIN
# 4     1031007253         BITCOIN
# ...          ...             ...
# 7671   813644704  CRYPTOCURRENCY
# 7672   813675290  CRYPTOCURRENCY
# 7673   813604394  CRYPTOCURRENCY
# 7674   813485027         BITCOIN
# 7675   813515698  CRYPTOCURRENCY
#
#                                                    Link      Date Country  \
# 0     https://www.newsweek.com/ukraine-military-russ...  20220228      RS
# 1     https://www.msn.com/en-us/news/technology/bitc...  20220228      UK
# 2     https://www.datacenterdynamics.com/en/news/kaz...  20220228      CH
# 3     https://www.news.com.au/finance/markets/world-...  20220228      UP
# 4     https://www.theverge.com/2022/2/28/22954859/bi...  20220228      CH
# ...                                                 ...       ...     ...
# 7671  https://www.express.co.uk/finance/city/1065997...  20190102      IN
# 7672  https://www.business-standard.com/article/pti-...  20190102      IN
# 7673  https://www.newsbtc.com/2019/01/02/india-still...  20190102      IN
# 7674  https://news.bitcoin.com/rick-falkvinge-immine...  20190101      SW
# 7675  https://hothardware.com/news/nvidia-faces-clas...  20190101      US
#
#       GoldsteinScale   AvgTone  ClosingPrice  \
# 0                7.0 -1.848233      43193.23
# 1                7.0 -1.716738      43193.23
# 2                2.8 -3.966006      43193.23
# 3                3.0 -4.796512      43193.23
# 4                2.8 -1.856705      43193.23
# ...              ...       ...           ...
# 7671             3.4 -0.856531       3943.41
# 7672             3.4 -6.236701       3943.41
# 7673             1.0 -1.784789       3943.41
# 7674             0.4 -2.995680       3843.52
# 7675             4.0 -2.925990       3843.52
#
#                                                    news
# 0     ukraine military russia invasion war 20 millio...
# 1     bitcoin mining is less green than ever after l...
# 2     kazakhstan government shuts down 13 illegal bi...
# 3     investors flee bitcoin price warning as war es...
# 4                    bitcoin mining pollution china ban
# ...                                                 ...
# 7671  bitcoin price latest news updates btc india cr...
# 7672  j k police warns against investing in cryptocu...
# 7673  india still cautious over crypto rbi shelves p...
# 7674  rick falkvinge imminent financial crisis perfe...
# 7675  nvidia faces class action lawsuit cryptocurren...
#
# [7676 rows x 9 columns]

# %%
df.iloc[0,8]
# Out:
# 'ukraine military russia invasion war 20 million crypto donations bitcoin ethereum 1683159'

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(df.iloc[:,8].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F88C824B280>
