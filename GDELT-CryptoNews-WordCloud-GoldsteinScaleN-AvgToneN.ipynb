# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("GDELT-CryptoNews-WordCloud-GoldsteinScaleN-AvgToneN.xlsx")

# %%
df
# Out:
#               ID  Classification  \
# 0     1030957178         BITCOIN
# 1     1030838195         BITCOIN
# 2     1030829521         BITCOIN
# 3     1030873105         BITCOIN
# 4     1030814106         BITCOIN
# ...          ...             ...
# 7736   813553870  CRYPTOCURRENCY
# 7737   813681049  CRYPTOCURRENCY
# 7738   813540269         BITCOIN
# 7739   813466107         BITCOIN
# 7740   813467504  CRYPTOCURRENCY
#
#                                                    Link      Date Country  \
# 0     https://markets.businessinsider.com/news/curre...  20220228      US
# 1     https://economictimes.indiatimes.com/markets/c...  20220228      KS
# 2     https://forextv.com/bitcoin-news/investors-fle...  20220228      UP
# 3     https://menafn.com/1103773134/Bitcoin-Hackers-...  20220228      UK
# 4     https://www.investing.com/news/cryptocurrency-...  20220228      UP
# ...                                                 ...       ...     ...
# 7736  https://cointelegraph.com/news/government-of-a...  20190102      CH
# 7737  https://www.forbes.com/sites/eladnatanson/2019...  20190102      IN
# 7738  https://news.bitcoin.com/abkhazia-temporarily-...  20190101      RS
# 7739  https://www.afr.com/opinion/jamie-dimon-and-wa...  20190101      XX
# 7740  https://www.financemagnates.com/cryptocurrency...  20190101      IR
#
#       GoldsteinScale    AvgTone  ClosingPrice  \
# 0               -2.0  -6.798246      43193.23
# 1               -0.4  -2.536232      43193.23
# 2               -7.0 -22.222222      43193.23
# 3               -4.0  -4.248366      43193.23
# 4               -0.4  -3.286385      43193.23
# ...              ...        ...           ...
# 7736            -0.4  -1.445087       3943.41
# 7737            -5.0  -1.589103       3943.41
# 7738            -5.0  -1.818182       3843.52
# 7739            -0.4  -0.063943       3843.52
# 7740            -4.4  -3.773585       3843.52
#
#                                                    news
# 0     bitcoin bitconnect fraud ponzi scheme indictme...
# 1                  bitcoin steady amid ukraine conflict
# 2     investors flee bitcoin price warning as war es...
# 3     bitcoin hackers run wild again cyber forensics...
# 4          bitcoin steady amid ukraine conflict 2773248
# ...                                                 ...
# 7736  government of abkhazia cuts off power to 15 cr...
# 7737  facebook cryptocurrency and the future of mobi...
# 7738    abkhazia temporarily shuts down 15 mining farms
# 7739  jamie dimon and warren buffett have last laugh...
# 7740  iran criminalizes use of telegrams cryptocurrency
#
# [7741 rows x 9 columns]

# %%
df.iloc[0,8]
# Out:
# 'bitcoin bitconnect fraud ponzi scheme indictment jury sec crypto blockchain 2022 2'

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(df.iloc[:,8].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FD571B539A0>
