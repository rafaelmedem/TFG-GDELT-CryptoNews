# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("GDELT-CryptoNews-WordCloud-MostRelevant-FinBert-Negative.xlsx")

# %%
df
# Out:
#              ID  Classification  \
# 0     813540269         BITCOIN
# 1     813553870  CRYPTOCURRENCY
# 2     813985016         BITCOIN
# 3     814238511         BITCOIN
# 4     814362763         BITCOIN
# ..          ...             ...
# 453  1029963508         BITCOIN
# 454  1030046296         BITCOIN
# 455  1030610798         BITCOIN
# 456  1030693171         BITCOIN
# 457  1030948253         BITCOIN
#
#                                                   Link      Date Country  \
# 0    https://news.bitcoin.com/abkhazia-temporarily-...  20190101      RS
# 1    https://cointelegraph.com/news/government-of-a...  20190102      CH
# 2    https://cointelegraph.com/news/bitcoin-atm-pro...  20190104      XX
# 3    https://www.sgtreport.com/2019/01/bitcoin-atm-...  20190105      JA
# 4    https://news.bitcoin.com/coinbase-and-its-trou...  20190106      IR
# ..                                                 ...       ...     ...
# 453  https://investorsking.com/2022/02/22/naira-exc...  20220223      RS
# 454  https://www.msn.com/en-us/money/markets/bitcoi...  20220224      RS
# 455  https://www.msn.com/en-us/money/markets/bitcoi...  20220226      CH
# 456  https://kvia.com/news/2022/02/26/bitcoin-is-ge...  20220227      CH
# 457  https://www.datacenterdynamics.com/en/news/kaz...  20220228      CH
#
#      GoldsteinScale   AvgTone  ClosingPrice  \
# 0              -5.0 -1.818182       3843.52
# 1              -0.4 -1.445087       3943.41
# 2              -4.0 -0.269542       3857.72
# 3              -4.4 -0.604230       3845.19
# 4               0.0 -5.170517       4076.63
# ..              ...       ...           ...
# 453             0.0 -3.508772      37296.57
# 454             7.0 -5.503351      38332.61
# 455             4.0 -1.960784      39105.15
# 456             4.0 -2.331002      37709.78
# 457             2.8 -3.966006      43193.23
#
#                                                   news  finbert_positive  \
# 0      abkhazia temporarily shuts down 15 mining farms          0.008346
# 1    government of abkhazia cuts off power to 15 cr...          0.009233
# 2    bitcoin atm producer moves to switzerland due ...          0.010728
# 3    bitcoin atm producer moves to switzerland due ...          0.010728
# 4    coinbase and its troubling history of customer...          0.008150
# ..                                                 ...               ...
# 453  naira exchange rates mixed against dollar poun...          0.029184
# 454  bitcoin drops 8 and other cryptocurrencies tum...          0.015961
# 455                    bitcoin is getting even dirtier          0.011602
# 456                    bitcoin is getting even dirtier          0.011602
# 457  kazakhstan government shuts down 13 illegal bi...          0.009341
#
#      finbert_negative  finbert_neutral  max_value   finbert
# 0            0.960204         0.031451   0.960204  negative
# 1            0.950131         0.040636   0.950131  negative
# 2            0.956244         0.033028   0.956244  negative
# 3            0.956244         0.033028   0.956244  negative
# 4            0.961461         0.030389   0.961461  negative
# ..                ...              ...        ...       ...
# 453          0.957620         0.013197   0.957620  negative
# 454          0.957955         0.026084   0.957955  negative
# 455          0.951425         0.036972   0.951425  negative
# 456          0.951425         0.036972   0.951425  negative
# 457          0.954086         0.036574   0.954086  negative
#
# [458 rows x 14 columns]

# %%
df.iloc[0,8]
# Out:
# 'abkhazia temporarily shuts down 15 mining farms'

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(df.iloc[:,8].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F95C9580190>
