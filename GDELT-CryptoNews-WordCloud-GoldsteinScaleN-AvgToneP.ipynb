# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("GDELT-CryptoNews-WordCloud-GoldsteinScaleN-AvgToneP.xlsx")

# %%
df
# Out:
#               ID  Classification  \
# 0     1030784865         BITCOIN
# 1     1030592111  CRYPTOCURRENCY
# 2     1030646496  CRYPTOCURRENCY
# 3     1030000826         BITCOIN
# 4     1030085408         BITCOIN
# ...          ...             ...
# 1758   814116539         BITCOIN
# 1759   813814237         BITCOIN
# 1760   813745863  CRYPTOCURRENCY
# 1761   813847371  CRYPTOCURRENCY
# 1762   813517140  CRYPTOCURRENCY
#
#                                                    Link      Date Country  \
# 0     https://bitcoinmagazine.com/business/buying-an...  20220227      US
# 1     https://www.thestreet.com/investing/cryptocurr...  20220226      CH
# 2     https://edmontonjournal.com/news/local-news/gl...  20220226      CA
# 3     https://www.stripes.com/theaters/us/2022-02-23...  20220224      CH
# 4     https://kuow.org/stories/how-the-u-s-benefits-...  20220224      CH
# ...                                                 ...       ...     ...
# 1758  https://www.freep.com/story/opinion/readers/20...  20190104      US
# 1759  https://thebitcoinnews.com/carrefours-blockcha...  20190103      SP
# 1760  https://cointelegraph.com/news/new-york-assemb...  20190103      US
# 1761  https://www.coinspeaker.com/new-york-cryptocur...  20190103      US
# 1762  http://en.rfi.fr/africa/20190101-cameroon-sepa...  20190101      US
#
#       GoldsteinScale   AvgTone  ClosingPrice  \
# 0               -4.0  1.490826      37709.78
# 1               -2.0  2.396804      39105.15
# 2               -6.5  1.200000      39105.15
# 3               -5.0  0.856531      38332.61
# 4               -2.0  0.172295      38332.61
# ...              ...       ...           ...
# 1758            -5.0  0.331126       3857.72
# 1759            -2.0  3.713366       3836.74
# 1760            -2.0  0.492614       3836.74
# 1761            -7.0  1.509434       3836.74
# 1762            -2.0  0.640548       3843.52
#
#                                                    news
# 0           buying and selling real estate with bitcoin
# 1     this model and instagram influencer builds an ...
# 2     glenrose first health care foundation in alber...
# 3     intel chip challenges reign of china bitcoin m...
# 4     how the u s benefits when china turns its back...
# ...                                                 ...
# 1758  bitcoin cryptocurrency could change how we pay...
# 1759     carrefours blockchain in spain is already live
# 1760  new york assemblyman announces creation of fir...
# 1761                 new york cryptocurrency task force
# 1762  20190101 cameroon separatists sell ambazonia c...
#
# [1763 rows x 9 columns]

# %%
df.iloc[0,8]
# Out:
# 'buying and selling real estate with bitcoin'

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(df.iloc[:,8].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FF0F85CCE80>
