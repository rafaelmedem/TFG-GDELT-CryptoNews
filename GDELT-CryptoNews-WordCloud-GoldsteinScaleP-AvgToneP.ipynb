# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("GDELT-CryptoNews-WordCloud-GoldsteinScaleP-AvgToneP.xlsx")

# %%
df
# Out:
#               ID Classification  \
# 0     1030834711        BITCOIN
# 1     1030961244        BITCOIN
# 2     1030968768        BITCOIN
# 3     1030883563        BITCOIN
# 4     1030818602        BITCOIN
# ...          ...            ...
# 5906   813640181        BITCOIN
# 5907   813609521        BITCOIN
# 5908   813699827        BITCOIN
# 5909   813500424        BITCOIN
# 5910   813535638        BITCOIN
#
#                                                    Link      Date Country  \
# 0     https://foreignaffairs.co.nz/2022/02/28/mil-os...  20220228      JM
# 1     https://marylandreporter.com/2022/02/28/bitcoi...  20220228      XX
# 2     https://bitcoinke.io/2022/02/we-will-introduce...  20220228      SF
# 3     http://www.itechpost.com/articles/109318/20220...  20220228      UP
# 4     https://www.asiaone.com/business/cs-global-par...  20220228      ES
# ...                                                 ...       ...     ...
# 5906  http://www.rttnews.com/2966290/ice-s-bitcoin-s...  20190102      US
# 5907  https://www.pulse.ng/bi/finance/bitcoin-price-...  20190102      XX
# 5908  https://thebitcoinnews.com/why-ohios-state-tre...  20190102      XX
# 5909  https://www.finanzen.at/nachrichten/aktien/ins...  20190101      US
# 5910  https://insidebitcoins.com/news/268-andy-bromb...  20190101      XX
#
#       GoldsteinScale   AvgTone  ClosingPrice  \
# 0                3.0  2.826511      43193.23
# 1               10.0  4.676019      43193.23
# 2                3.0  0.519481      43193.23
# 3                5.2  1.069519      43193.23
# 4                7.0  2.692117      43193.23
# ...              ...       ...           ...
# 5906             7.4  1.509434       3943.41
# 5907             1.0  1.812689       3943.41
# 5908             1.0  1.358491       3943.41
# 5909             7.4  1.350541       3843.52
# 5910             1.0  2.298851       3843.52
#
#                                                    news
# 0     mil osi cs global partners bitcoin heaven el s...
# 1     bitcoin trader reviews real or fake trading ap...
# 2     we will introduce crypto laws in 2022 says tre...
# 3     ukraine raises 10 million crypto donations eur...
# 4     cs global partners bitcoin heaven el salvador ...
# ...                                                 ...
# 5906    ice s bitcoin startup bakkt raises 182 mln aspx
# 5907  bitcoin price to fall further in 2019 heres wh...
# 5908  why ohios state treasurer backs decision to ac...
# 5909  institutional capital to spark bitcoin rally s...
# 5910  268 andy bromberg coinlist capital formation f...
#
# [5911 rows x 9 columns]

# %%
df.iloc[0,8]
# Out:
# 'mil osi cs global partners bitcoin heaven el salvador newest nation to consider citizenship by investment'

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(df.iloc[:,8].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FB01290A2B0>
