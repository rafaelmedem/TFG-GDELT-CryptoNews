# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("GDELT-CryptoNews-WordCloud-MostRelevant-FinBert-Neutral.xlsx")

# %%
df
# Out:
#              ID  Classification  \
# 0     813757688         BITCOIN
# 1     814558950  CRYPTOCURRENCY
# 2     815117101  CRYPTOCURRENCY
# 3     815609061         BITCOIN
# 4     815930893         BITCOIN
# ..          ...             ...
# 629  1028632822         BITCOIN
# 630  1028933615  CRYPTOCURRENCY
# 631  1029098837         BITCOIN
# 632  1029233177  CRYPTOCURRENCY
# 633  1030364423         BITCOIN
#
#                                                   Link      Date Country  \
# 0    https://news.yahoo.com/bitcoin-cash-single-min...  20190103      CH
# 1    https://thenextweb.com/hardfork/2019/01/07/col...  20190107      US
# 2    https://ipolitics.ca/2019/01/09/elections-cana...  20190109      CA
# 3    https://www.coinspeaker.com/bitwise-bitcoin-et...  20190111      XX
# 4    https://mrtopstep.com/japanese-regulator-clari...  20190113      JA
# ..                                                 ...       ...     ...
# 629  https://cryptopotato.com/bulgaria-stock-exchan...  20220216      BU
# 630  https://economictimes.indiatimes.com/markets/c...  20220218      XX
# 631  https://www.houstonpress.com/news/does-bitcoin...  20220219      US
# 632  https://www.wwaytv3.com/trading-cryptocurrency...  20220220      US
# 633  https://www.thehindu.com/news/national/clarify...  20220225      IN
#
#      GoldsteinScale   AvgTone  ClosingPrice  \
# 0              -2.0 -2.766492       3836.74
# 1               3.0 -0.913242       4025.25
# 2               1.0  0.674157       4035.30
# 3               3.0  1.877934       3687.37
# 4               5.0 -1.488192       3552.95
# ..              ...       ...           ...
# 629            -4.0 -1.934236      43961.86
# 630            -5.0 -5.702131      40030.98
# 631            -4.0  0.466563      40122.15
# 632             3.0 -0.277060      38431.38
# 633             0.0 -2.205882      39214.22
#
#                                                   news  finbert_positive  \
# 0            bitcoin cash single mining pool 013516813          0.029471
# 1                   colarado cryptocurrency securities          0.030677
# 2    elections canada launches consultations on cry...          0.028314
# 3                              bitwise bitcoin etf sec          0.030715
# 4    japanese regulator clarifies stance on bitcoin...          0.029784
# ..                                                 ...               ...
# 629  bulgaria stock exchange lists bitcoin and ethe...          0.026564
# 630  fbi to form digital currency unit justice dept...          0.045825
# 631   does bitcoin belong in texas government 12803336          0.029316
# 632  trading cryptocurrency you must report these t...          0.022753
# 633   clarify on the legality of bitcoin sc tells govt          0.030266
#
#      finbert_negative  finbert_neutral  max_value  finbert
# 0            0.027175         0.943354   0.943354  neutral
# 1            0.019716         0.949607   0.949607  neutral
# 2            0.026375         0.945311   0.945311  neutral
# 3            0.020448         0.948837   0.948837  neutral
# 4            0.022817         0.947399   0.947399  neutral
# ..                ...              ...        ...      ...
# 629          0.021142         0.952294   0.952294  neutral
# 630          0.019180         0.934995   0.934995  neutral
# 631          0.029304         0.941380   0.941380  neutral
# 632          0.033509         0.943738   0.943738  neutral
# 633          0.022211         0.947524   0.947524  neutral
#
# [634 rows x 14 columns]

# %%
df.iloc[0,8]
# Out:
# 'bitcoin cash single mining pool 013516813'

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(df.iloc[:,8].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FD840DE9CD0>
