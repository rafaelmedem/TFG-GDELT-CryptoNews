# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("GDELT-CryptoNews-BQ-and-Bitcoin-ClosingPrice-WithNews-WithFinBert-MostRelevant-ByDate.xlsx")

# %%
df
# Out:
#               ID  Classification  \
# 0      813540269         BITCOIN
# 1      813553870  CRYPTOCURRENCY
# 2      813757688         BITCOIN
# 3      813985016         BITCOIN
# 4      814238511         BITCOIN
# ...          ...             ...
# 1141  1030046296         BITCOIN
# 1142  1030364423         BITCOIN
# 1143  1030610798         BITCOIN
# 1144  1030693171         BITCOIN
# 1145  1030948253         BITCOIN
#
#                                                    Link      Date Country  \
# 0     https://news.bitcoin.com/abkhazia-temporarily-...  20190101      RS
# 1     https://cointelegraph.com/news/government-of-a...  20190102      CH
# 2     https://news.yahoo.com/bitcoin-cash-single-min...  20190103      CH
# 3     https://cointelegraph.com/news/bitcoin-atm-pro...  20190104      XX
# 4     https://www.sgtreport.com/2019/01/bitcoin-atm-...  20190105      JA
# ...                                                 ...       ...     ...
# ...

# %%
positive_df = df.loc[(df["finbert"] == "positive")]

# %%
positive_df
# Out:
#               ID  Classification  \
# 9      815209176         BITCOIN
# 95     836623760         BITCOIN
# 145    848048133         BITCOIN
# 170    854242125         BITCOIN
# 180    856465960  CRYPTOCURRENCY
# 191    858988230         BITCOIN
# 245    870609431         BITCOIN
# 252    872340780         BITCOIN
# 300    883221039         BITCOIN
# 334    890548290  CRYPTOCURRENCY
# 359    895539830         BITCOIN
# 384    901254740         BITCOIN
# 387    901789438         BITCOIN
# 394    903363161         BITCOIN
# 401    904913479         BITCOIN
# 443    914250764         BITCOIN
# 453    916202163         BITCOIN
# 454    916369854         BITCOIN
# 456    916656308         BITCOIN
# 471    919374080         BITCOIN
# 494    923736262         BITCOIN
# 496    924043735         BITCOIN
# 511    926736181         BITCOIN
# 513    927261232         BITCOIN
# 525    929561872         BITCOIN
# 538    932039273         BITCOIN
# 562    936488433         BITCOIN
# ...

# %%
positive_df.to_excel("GDELT-CryptoNews-WordCloud-MostRelevant-FinBert-Positive.xlsx",index=False)

# %%
negative_df = df.loc[(df["finbert"] == "negative")]

# %%
negative_df
# Out:
#               ID  Classification  \
# 0      813540269         BITCOIN
# 1      813553870  CRYPTOCURRENCY
# 3      813985016         BITCOIN
# 4      814238511         BITCOIN
# 5      814362763         BITCOIN
# ...          ...             ...
# 1140  1029963508         BITCOIN
# 1141  1030046296         BITCOIN
# 1143  1030610798         BITCOIN
# 1144  1030693171         BITCOIN
# 1145  1030948253         BITCOIN
#
#                                                    Link      Date Country  \
# 0     https://news.bitcoin.com/abkhazia-temporarily-...  20190101      RS
# 1     https://cointelegraph.com/news/government-of-a...  20190102      CH
# 3     https://cointelegraph.com/news/bitcoin-atm-pro...  20190104      XX
# 4     https://www.sgtreport.com/2019/01/bitcoin-atm-...  20190105      JA
# 5     https://news.bitcoin.com/coinbase-and-its-trou...  20190106      IR
# ...                                                 ...       ...     ...
# ...

# %%
negative_df.to_excel("GDELT-CryptoNews-WordCloud-MostRelevant-FinBert-Negative.xlsx",index=False)

# %%
neutral_df = df.loc[(df["finbert"] == "neutral")]

# %%
neutral_df
# Out:
#               ID  Classification  \
# 2      813757688         BITCOIN
# 6      814558950  CRYPTOCURRENCY
# 8      815117101  CRYPTOCURRENCY
# 10     815609061         BITCOIN
# 12     815930893         BITCOIN
# ...          ...             ...
# 1133  1028632822         BITCOIN
# 1135  1028933615  CRYPTOCURRENCY
# 1136  1029098837         BITCOIN
# 1137  1029233177  CRYPTOCURRENCY
# 1142  1030364423         BITCOIN
#
#                                                    Link      Date Country  \
# 2     https://news.yahoo.com/bitcoin-cash-single-min...  20190103      CH
# 6     https://thenextweb.com/hardfork/2019/01/07/col...  20190107      US
# 8     https://ipolitics.ca/2019/01/09/elections-cana...  20190109      CA
# 10    https://www.coinspeaker.com/bitwise-bitcoin-et...  20190111      XX
# 12    https://mrtopstep.com/japanese-regulator-clari...  20190113      JA
# ...                                                 ...       ...     ...
# ...

# %%
neutral_df.to_excel("GDELT-CryptoNews-WordCloud-MostRelevant-FinBert-Neutral.xlsx",index=False)
